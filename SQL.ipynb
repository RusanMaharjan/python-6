# %%
import sqlite3

# %%
conn = sqlite3.connect('sql.db')

# %%
# Query communication between python and sqlite database
cursor = conn.cursor()

# %%
try:
    cursor.execute('''
        Create Table Customers (
        	customer_id integer primary key autoincrement,
        	customer_name text,
        	customer_address text,
        	phone text,
        	-- premium, normal, vip
        	customer_type text
        );
    ''')
    print('Customer created successfully.')
except:
    print('Customer table already created.')
# Out:
# Customer table already created.

# %%
try:
    cursor.execute('''
        Create Table Staffs (
            staff_id integer primary key autoincrement,
            staff_name text,
            staff_phone text,
            -- senior, associate, junior
            job_position text,
            -- Full-Time, Part-Time, Contract
            job_type text
        );
    ''')
    print('Staff created successfully.')
except:
    print('Staff table already created.')
# Out:
# Staff table already created.

# %%
try:
    cursor.execute('''
        create table orders (
            order_id integer primary key autoincrement,
            order_date date,
            -- completed, pending, processing, rejected
            order_status text,
            order_quantity integer,
            order_price real,
            order_destination text,
            customer_id integer,
            staff_id integer,
            foreign key (customer_id) references customers (customer_id),
            foreign key (staff_id) references staffs (staff_id)
        )
    ''')
    print('Orders created successfully.')
except:
    print('Orders table already created.')
# Out:
# Orders table already created.

# %% [markdown]
# ## Insert data into table

# %%
try:
    cursor.execute('''
        Insert into Customers (customer_name, customer_address, phone, customer_type)
        VALUES 
        ('Aurthur Morgan', 'Itahari', '7654321789', 'VIP')
    ''')
    conn.commit()
    print('Customer data inserted successfully.')
except:
    print('Customer data insert failed.')
# Out:
# Customer data inserted successfully.

# %%
try:
    cursor.execute('''
        INSERT INTO Staffs (staff_name, staff_phone, job_position, job_type) VALUES
        ('John Smith', '555-1001', 'senior', 'Full-Time'),
        ('Emily Johnson', '555-1002', 'associate', 'Full-Time'),
        ('Michael Brown', '555-1003', 'junior', 'Part-Time'),
        ('Sarah Davis', '555-1004', 'associate', 'Contract'),
        ('David Wilson', '555-1005', 'senior', 'Full-Time');
    ''')
    conn.commit()
    print('Staff data inserted successfully.')
except:
    print('Staff data insert failed.')
# Out:
# Staff data inserted successfully.

# %%
try:
    cursor.execute('''
        INSERT INTO orders (
            order_date,
            order_status,
            order_quantity,
            order_price,
            order_destination,
            customer_id,
            staff_id
        ) VALUES
        ('2026-01-02', 'completed', 5, 250.00, 'Bhaktapur', 1, 1),
        ('2026-01-03', 'pending', 2, 120.50, 'Kathmandu', 2, 2),
        ('2026-01-04', 'processing', 8, 420.75, 'Jhapa', 3, 3),
        ('2026-01-05', 'completed', 3, 180.00, 'Lalitpur', 4, 4),
        ('2026-01-06', 'rejected', 1, 50.00, 'Kavre', 5, 5),
        
        ('2026-01-07', 'completed', 10, 750.00, 'Bhaktapur', 1, 2),
        ('2026-01-08', 'processing', 4, 200.00, 'Kathmandu', 2, 3),
        ('2026-01-09', 'pending', 6, 315.50, 'Jhapa', 3, 4),
        ('2026-01-10', 'completed', 7, 490.25, 'Lalitpur', 4, 5),
        ('2026-01-11', 'processing', 2, 110.00, 'Kavre', 5, 1),
        
        ('2026-01-12', 'completed', 9, 675.00, 'Bhaktapur', 1, 3),
        ('2026-01-13', 'pending', 3, 150.00, 'Kathmandu', 2, 4),
        ('2026-01-14', 'rejected', 5, 275.00, 'Jhapa', 3, 5),
        ('2026-01-15', 'completed', 12, 960.00, 'Lalitpur', 4, 1),
        ('2026-01-16', 'processing', 4, 220.00, 'Kavre', 5, 2),
        
        ('2026-01-17', 'pending', 8, 440.00, 'Bhaktapur', 1, 4),
        ('2026-01-18', 'completed', 6, 330.00, 'Kathmandu', 2, 5),
        ('2026-01-19', 'processing', 11, 880.00, 'Jhapa', 3, 1),
        ('2026-01-20', 'completed', 2, 95.50, 'Lalitpur', 4, 2),
        ('2026-01-21', 'pending', 7, 385.00, 'Kavre', 5, 3),
        
        ('2026-01-22', 'completed', 5, 265.00, 'Bhaktapur', 1, 5),
        ('2026-01-23', 'processing', 9, 720.00, 'Kathmandu', 2, 1),
        ('2026-01-24', 'rejected', 3, 140.00, 'Jhapa', 3, 2),
        ('2026-01-25', 'completed', 15, 1125.00, 'Lalitpur', 4, 3),
        ('2026-01-26', 'processing', 4, 210.00, 'Kavre', 5, 4),
        
        ('2026-01-27', 'completed', 6, 360.00, 'Bhaktapur', 1, 1),
        ('2026-01-28', 'pending', 8, 520.00, 'Kathmandu', 2, 2),
        ('2026-01-29', 'processing', 10, 790.00, 'Jhapa', 3, 3),
        ('2026-01-30', 'completed', 5, 295.00, 'Lalitpur', 4, 4),
        ('2026-01-31', 'pending', 7, 455.00, 'Kavre', 5, 5);
    ''')
    conn.commit()
    print('Orders data inserted successfully.')
except:
    print('Orders data insert failed.')
# Out:
# Orders data inserted successfully.

# %% [markdown]
# ## Update data

# %%
try:
    cursor.execute('''
        update customers set customer_address='Itahari', phone='9876554432'
        where customer_id=5;
    ''')
    conn.commit()
    print('Customer data updated successfully.')
except:
    print('Customer data update failed.')
# Out:
# Customer data updated successfully.

# %% [markdown]
# ## Delete data

# %%
try:
    cursor.execute('''
        delete from customers where customer_id in (4, 5, 6);
    ''')
    conn.commit()
    print('Customer data deleted successfully.')
except:
    print('Customer data delete failed.')

# %% [markdown]
# ## Select data

# %%
try:
    cursor.execute('''
        select * from customers;
    ''')
    data = cursor.fetchall()
    for row in data:
        print(row)
except:
    print('Table customers doesnot exist.')
# Out:
# (1, 'Jhon Doe', 'Bhaktapur', '9876543210', 'Premium')
# (2, 'Bill Morgan', 'Kathmandu', '9877654568', 'Normal')
# (3, 'Sadie Adler', 'Jhapa', '5434567890', 'Normal')
# (4, 'Ram Bahadur', 'Lalitpur', '9876543432', 'Premium')
# (5, 'Jhon Marsten', 'Kavre', '9876544321', 'VIP')

# %%
try:
    cursor.execute('''
        select * from orders where order_destination like '%ha%';
    ''')
    data = cursor.fetchall()
    for row in data:
        print(row)
except:
    print('No data found.')
# Out:
# (1, '2026-01-02', 'completed', 5, 250.0, 'Bhaktapur', 1, 1)
# (3, '2026-01-04', 'processing', 8, 420.75, 'Jhapa', 3, 3)
# (6, '2026-01-07', 'completed', 10, 750.0, 'Bhaktapur', 1, 2)
# (8, '2026-01-09', 'pending', 6, 315.5, 'Jhapa', 3, 4)
# (11, '2026-01-12', 'completed', 9, 675.0, 'Bhaktapur', 1, 3)
# (13, '2026-01-14', 'rejected', 5, 275.0, 'Jhapa', 3, 5)
# (16, '2026-01-17', 'pending', 8, 440.0, 'Bhaktapur', 1, 4)
# (18, '2026-01-19', 'processing', 11, 880.0, 'Jhapa', 3, 1)
# (21, '2026-01-22', 'completed', 5, 265.0, 'Bhaktapur', 1, 5)
# (23, '2026-01-24', 'rejected', 3, 140.0, 'Jhapa', 3, 2)
# (26, '2026-01-27', 'completed', 6, 360.0, 'Bhaktapur', 1, 1)
# (28, '2026-01-29', 'processing', 10, 790.0, 'Jhapa', 3, 3)
